# %% [markdown]
# # For looping externally to a set of multiple pages

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
headers = {
    'authority': 'huntr.co',
    'sec-ch-ua': '^\\^',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://huntr.co/jobs',
    'accept-language': 'en-US,en;q=0.9,ur;q=0.8,zh-CN;q=0.7,zh;q=0.6',
    'cookie': '_ga=GA1.2.887631085.1620941683; _gid=GA1.2.1959015238.1620941683; mp_1d6f823f8d5432354b55fc0af879343c_mixpanel=^%^7B^%^22distinct_id^%^22^%^3A^%^20^%^2217967a730c241-088b1bcbf61357-2363163-144000-17967a730c3665^%^22^%^2C^%^22^%^24device_id^%^22^%^3A^%^20^%^2217967a730c241-088b1bcbf61357-2363163-144000-17967a730c3665^%^22^%^2C^%^22^%^24initial_referrer^%^22^%^3A^%^20^%^22^%^24direct^%^22^%^2C^%^22^%^24initial_referring_domain^%^22^%^3A^%^20^%^22^%^24direct^%^22^%^7D',
}
data_list = []
for i in range(5):
    params = (
        ('page', str(i)),
        ('zoom', '1'),
    )

    response = requests.get('https://huntr.co/public/search/job-posts', headers=headers, params=params)
    json_response = response.json()
    json_response = response.json()
    for listing in json_response["results"]:
        data_dict = {}
        data_dict["Employ"] = listing["_employer"]
        data_dict["link"] = listing["url"]
        data_dict["Identity"] = listing["_id"]

        try:
            data_dict["Adress"] = listing["places"][0]["address"]
        except:
            data_dict["Adress"] = ""

        try:
            data_dict["Country"] = listing["places"][0]["country"]
        except: 
            data_dict["Country"] = ""

        try:
            data_dict["longitude"] = listing["places"][0]["point"]["coordinates"][0]
        except:
            data_dict["longitude"] = ""

        try:
            data_dict["latitude"] = listing["places"][0]["point"]["coordinates"][1]
        except:
            data_dict["latitude"] = ""

        try:
            data_dict["Orignal Location"] = listing["places"][0]["originalLocation"].strip("/")
        except:
            data_dict["Orignal Location"] = ""

        try:
            data_dict["Skills"] = listing["_skills"] #needed
        except:
            data_dict["Skills"] = ""

        try:
            data_dict["Description"] = listing["textDescription"]
        except:
            data_dict["Description"] = ""
        data_dict["Date"] = listing["postDate"]

        data_list.append(data_dict)
        
    df = pd.DataFrame(data_list)

# %% [markdown]
# # For getting data of a specific page

# %%
import requests

headers = {
    'authority': 'huntr.co',
    'sec-ch-ua': '^\\^',
    'accept': 'application/json, text/plain, */*',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://huntr.co/jobs',
    'accept-language': 'en-US,en;q=0.9,ur;q=0.8,zh-CN;q=0.7,zh;q=0.6',
    'cookie': '_ga=GA1.2.887631085.1620941683; _gid=GA1.2.1959015238.1620941683; mp_1d6f823f8d5432354b55fc0af879343c_mixpanel=^%^7B^%^22distinct_id^%^22^%^3A^%^20^%^2217967a730c241-088b1bcbf61357-2363163-144000-17967a730c3665^%^22^%^2C^%^22^%^24device_id^%^22^%^3A^%^20^%^2217967a730c241-088b1bcbf61357-2363163-144000-17967a730c3665^%^22^%^2C^%^22^%^24initial_referrer^%^22^%^3A^%^20^%^22^%^24direct^%^22^%^2C^%^22^%^24initial_referring_domain^%^22^%^3A^%^20^%^22^%^24direct^%^22^%^7D',
}
def get_dataframe(num):
    data_list = []
    params = (
        ('page', str(num)),
        ('zoom', '1'),
    )

    response = requests.get('https://huntr.co/public/search/job-posts', headers=headers, params=params)
    json_response = response.json()
    json_response = response.json()
    for listing in json_response["results"]:
        data_dict = {}
        data_dict["Employ"] = listing["_employer"]
        data_dict["link"] = listing["url"]
        data_dict["Identity"] = listing["_id"]

        try:
            data_dict["Adress"] = listing["places"][0]["address"]
        except:
            data_dict["Adress"] = ""

        try:
            data_dict["Country"] = listing["places"][0]["country"]
        except: 
            data_dict["Country"] = ""

        try:
            data_dict["longitude"] = listing["places"][0]["point"]["coordinates"][0]
        except:
            data_dict["longitude"] = ""

        try:
            data_dict["latitude"] = listing["places"][0]["point"]["coordinates"][1]
        except:
            data_dict["latitude"] = ""

        try:
            data_dict["Orignal Location"] = listing["places"][0]["originalLocation"].strip("/")
        except:
            data_dict["Orignal Location"] = ""

        try:
            data_dict["Skills"] = listing["_skills"] #needed
        except:
            data_dict["Skills"] = ""

        try:
            data_dict["Description"] = listing["textDescription"]
        except:
            data_dict["Description"] = ""
        data_dict["Date"] = listing["postDate"]

        data_list.append(data_dict)
        
    df = pd.DataFrame(data_list)
    return df

# %%
df
# Out:
#                        Employ  \
# 0    5d4e0ebb8aa2f3002faf1b30
# 1    5db7ab0a2ec99d002f53c647
# 2    5db7ab0a2ec99d002f53c647
# 3    5dc1ecd9845cbd002f1b21f7
# 4    5d92925014c63a002f447fb8
# ..                        ...
# 145  5d3ba6705db34b002f41e805
# 146  5c80900e31b906001101687e
# 147  5d3ba6705db34b002f41e805
# 148  5cc3a28fe3a158002e3efe57
# 149  5c80900e31b906001101687e
#
#                                                   link  \
# 0    https://www.docusign.com/company/careers/open?...
# 1    https://recruit.hirebridge.com/v3/Jobs/JobDeta...
# 2    https://recruit.hirebridge.com/v3/Jobs/JobDeta...
# 3    https://jobs.eaton.com/jobs/099331?lang=en-us&...
# 4    https://careers.petco.com/job/12919992/aquatic...
# ..                                                 ...
# 145  https://jobs.americanexpress.com/us/jobs/21009...
# 146  https://www.kaiserpermanentejobs.org/job/oakla...
# 147  https://jobs.americanexpress.com/us/jobs/21010...
# ...

# %%
df.to_csv("Private API.csv")
